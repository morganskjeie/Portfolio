# %%
# Import Libraries

import pandas as pd
import seaborn as sns
import numpy as npy

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) #Adjusts the configuration of the plots we are creating

#Read in data

df = pd.read_csv(r'/Users/mattskjeie/Downloads/movies.csv')

# %%
# Let's look at the data

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Checking for missing data

for col in df.columns:
    pct_missing = npy.mean(df[col].isnull())
    print('{} - {}%'.format(col,pct_missing))
    
df = df.dropna()
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.0%
# gross - 0.0%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%
# year_correct - 0.0%

# %%
# Data types

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Converting data types

df['budget'] = pd.to_numeric(df['budget'], errors = 'coerce').fillna(0).astype(int)

df['gross'] = pd.to_numeric(df['gross'], errors = 'coerce').fillna(0).astype(int)

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
# Create correct yeear

df['year_correct'] = df['released'].str.extract(pat = '([0-9]{4})').astype(int)

df
# Out:
# /var/folders/8r/9bd8f5h922s1xxqkrx3z_2wc0000gn/T/ipykernel_21389/352128197.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year_correct'] = df['released'].str.extract(pat = '([0-9]{4})').astype(int)
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...

# %%
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name     rating      genre  year  \
# 5445                                      Avatar      PG-13     Action  2009
# 7445                           Avengers: Endgame      PG-13     Action  2019
# 3045                                     Titanic      PG-13      Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13     Action  2015
# 7244                      Avengers: Infinity War      PG-13     Action  2018
# ...                                          ...        ...        ...   ...
# 832                                  On the Edge      PG-13      Drama  1985
# 3425                              The Acid House    Unrated     Comedy  1998
# 835                            Came a Hot Friday         PG  Adventure  1985
# 836                            Wuthering Heights  Not Rated      Drama  1985
# 1825                   Strangers in Good Company         PG      Drama  1990
#
# ...

# %%
# Correlation to Revenue

# %%
# Scatterplot with budget vs revenue

plt.scatter(x=df['budget'], y=df['gross'])

plt.title('Budget vs Gross Earnings')

plt.xlabel('Gross Earnings')

plt.ylabel('Budget for Film')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name     rating      genre  year  \
# 5445                                      Avatar      PG-13     Action  2009
# 7445                           Avengers: Endgame      PG-13     Action  2019
# 3045                                     Titanic      PG-13      Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13     Action  2015
# 7244                      Avengers: Infinity War      PG-13     Action  2018
# ...                                          ...        ...        ...   ...
# 832                                  On the Edge      PG-13      Drama  1985
# 3425                              The Acid House    Unrated     Comedy  1998
# 835                            Came a Hot Friday         PG  Adventure  1985
# 836                            Wuthering Heights  Not Rated      Drama  1985
# 1825                   Strangers in Good Company         PG      Drama  1990
#
# ...

# %%
# Plot bdget vs gross using seaborn

sns.regplot(x='budget', y='gross', data=df, scatter_kws={'color': 'red'}, line_kws={'color': 'blue'})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
df.corr()
# Out:
# /var/folders/8r/9bd8f5h922s1xxqkrx3z_2wc0000gn/T/ipykernel_21389/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                   year     score     votes    budget     gross   runtime  \
# year          1.000000  0.102346  0.226895  0.314842  0.264716  0.120676
# score         0.102346  1.000000  0.411931  0.056781  0.188259  0.400574
# votes         0.226895  0.411931  1.000000  0.485301  0.632987  0.309366
# budget        0.314842  0.056781  0.485301  1.000000  0.750562  0.270042
# gross         0.264716  0.188259  0.632987  0.750562  1.000000  0.244942
# runtime       0.120676  0.400574  0.309366  0.270042  0.244942  1.000000
# year_correct  0.997466  0.109815  0.222317  0.305530  0.257703  0.120370
#
#               year_correct
# year              0.997466
# ...

# %%
correlation_matrix = df.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numeric Feature')

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')
# Out:
# /var/folders/8r/9bd8f5h922s1xxqkrx3z_2wc0000gn/T/ipykernel_21389/837700209.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr(method='pearson')
# Text(120.72222222222221, 0.5, 'Movie Features')

# %%
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name     rating      genre  year  \
# 5445                                      Avatar      PG-13     Action  2009
# 7445                           Avengers: Endgame      PG-13     Action  2019
# 3045                                     Titanic      PG-13      Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13     Action  2015
# 7244                      Avengers: Infinity War      PG-13     Action  2018
# ...                                          ...        ...        ...   ...
# 832                                  On the Edge      PG-13      Drama  1985
# 3425                              The Acid House    Unrated     Comedy  1998
# 835                            Came a Hot Friday         PG  Adventure  1985
# 836                            Wuthering Heights  Not Rated      Drama  1985
# 1825                   Strangers in Good Company         PG      Drama  1990
#
# ...

# %%
# Numerize Company

df_numerize = df

for col_name in df_numerize.columns:
    if(df_numerize[col_name].dtype == 'object'):
        df_numerize[col_name] = df_numerize[col_name].astype('category')
        df_numerize[col_name] = df_numerize[col_name].cat.codes
        
df_numerize
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     6506       6      6  1980      1685    8.4   927000.0      2544    3958
# 1     5498       6      1  1980      1472    5.8    65000.0      2233    1612
# 2     5073       4      0  1980      1751    8.7  1200000.0      1093    2534
# 3      282       4      4  1980      1472    7.7   221000.0      1279    1975
# 4     1016       6      4  1980      1523    7.3   108000.0      1037     511
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7652  5713       3      0  2020       490    6.8     3700.0      1076    1652
# 7653  6399       6      5  2020        91    5.4     2400.0      2475    3827
# 7656  6936       5      4  2020      1865    5.0      294.0      2470    3820
# 7658   789       6      6  2020      1091    6.6       35.0      1739    1051
# 7659  2626       3      9  2020      2120    3.4      447.0      1585    2434
#
# ...

# %%
correlation_matrix = df_numerize.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numeric Feature')

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')
# Out:
# Text(120.72222222222221, 0.5, 'Movie Features')
